# %%
my_documents = [
    "La programación en Python es clave para el trabajo con datos",
    "Los programadores en Java tienen un alto interés en pasar a Python",
    "La optimización de algoritmos es fundamental en el desarrollo de software",
    "Las bases de datos relacionales son esenciales para muchas aplicaciones",
    "El paradigma de programación funcional gana popularidad",
    "La seguridad informática es un tema crucial en el desarrollo de aplicaciones web",
    "Los lenguajes de programación modernos ofrecen abstracciones poderosas",
    "La inteligencia artificial está transformando diversas industrias",
    "El aprendizaje automático es una rama clave de la ciencia de datos",
    "Las interfaces de usuario intuitivas mejoran la experiencia del usuario",
    "La calidad del código es esencial para mantener un proyecto exitoso",
    "La agilidad en el desarrollo de software permite adaptarse a cambios rápidamente",
    "Las pruebas automatizadas son cruciales para garantizar la estabilidad del software",
    "La modularización del código facilita la colaboración en equipos de programadores",
    "El control de versiones es necesario para rastrear cambios en el código",
    "La documentación clara es fundamental para que otros entiendan el código",
    "La programación orientada a objetos promueve la reutilización de código",
    "La resolución de problemas es una habilidad esencial en la programación",
    "La optimización prematura puede llevar a código complicado y difícil de mantener",
    "El diseño de interfaces de usuario atractivas mejora la usabilidad de las aplicaciones",
    "El código limpio es esencial para facilitar el mantenimiento",
    "Los patrones de diseño son soluciones probadas para problemas comunes",
    "Las pruebas unitarias garantizan el correcto funcionamiento de las partes del código",
    "El desarrollo ágil prioriza la entrega continua de valor al cliente",
    "Los comentarios en el código deben ser claros y útiles",
    "La recursividad es una técnica poderosa en la programación",
    "Las bibliotecas de código abierto aceleran el desarrollo de software",
    "La virtualización permite una mejor utilización de los recursos de hardware",
    "La seguridad en la programación web es fundamental para prevenir ataques",
    "Los principios SOLID son fundamentales para el diseño de software robusto",
    "La arquitectura de microservicios permite escalar componentes individualmente",
    "La refactorización mejora la calidad del código sin cambiar su comportamiento",
    "Los sistemas distribuidos presentan desafíos en la sincronización de datos",
    "El enfoque DevOps une el desarrollo y las operaciones para una entrega eficiente",
    "Las bases de datos NoSQL son útiles para manejar datos no estructurados",
    "La agilidad en el desarrollo permite adaptarse a cambios del mercado",
    "Las buenas prácticas en el control de versiones facilitan la colaboración",
    "La programación concurrente mejora la eficiencia en sistemas multiusuario",
    "Los marcos de trabajo MVC separan la lógica de la interfaz de usuario",
    "La interacción entre aplicaciones se logra a través de APIs",
    "El machine learning permite a las máquinas aprender de los datos",
    "La analítica de datos ayuda a tomar decisiones basadas en información",
    "El diseño responsivo garantiza una experiencia consistente en diferentes dispositivos",
    "Las pruebas de carga verifican el rendimiento de las aplicaciones",
    "El enfoque centrado en el usuario mejora la usabilidad de las aplicaciones",
    "La programación reactiva es útil para manejar flujos de datos asincrónicos",
    "Los contenedores facilitan la implementación y el despliegue de aplicaciones",
    "La gestión de dependencias es esencial para administrar las bibliotecas externas",
    "La integración continua automatiza la verificación de cambios en el código",
    "El aprendizaje profundo es una rama avanzada del machine learning",
    "La depuración es una habilidad crucial para encontrar y corregir errores",
    "La criptografía protege la información sensible en aplicaciones",
    "El desarrollo full-stack abarca tanto el frontend como el backend",
    "Las pruebas de seguridad ayudan a identificar vulnerabilidades en el software",
    "La agilidad cultural es clave para adoptar prácticas ágiles de manera efectiva",
    "La infraestructura como código permite automatizar la gestión de servidores",
    "Los patrones arquitectónicos guían la estructura general de una aplicación",
    "El análisis predictivo utiliza datos históricos para predecir tendencias",
    "Las interfaces API REST son ampliamente utilizadas para comunicarse con aplicaciones",
    "El rendimiento de las aplicaciones es esencial para brindar una buena experiencia",
    "La virtualización de servidores reduce costos y facilita la administración",
    "La ingeniería de software implica la aplicación de métodos sistemáticos",
    "El código autodocumentado es claro y fácil de entender para otros programadores",
    "La integración de sistemas conecta diferentes aplicaciones para trabajar juntas",
    "Las metodologías ágiles promueven la adaptación y la colaboración continua",
    "El monitoreo de aplicaciones permite identificar y resolver problemas en tiempo real",
    "El análisis de datos masivos (big data) abre oportunidades para obtener insights",
    "El diseño de interfaces de usuario es crucial para la experiencia del usuario",
    "La seguridad en el desarrollo es un proceso constante de mitigación de riesgos"
]

# %%
def cantidad_palabras(lista, cache={}):
    lista_palabras = {}
    for columna in my_documents:
        for palabra in columna.split():
            if palabra in lista_palabras:
                lista_palabras[palabra] += 1
            else:
                lista_palabras[palabra] = 1
    lista_ordenada = dict(sorted(lista_palabras.items(), key=lambda item: item[1], reverse=True))
    return lista_ordenada

# %%
cantidad_palabras(my_documents[1])
# Out:
# {'de': 59,
#  'La': 31,
#  'la': 27,
#  'en': 24,
#  'para': 23,
#  'el': 22,
#  'es': 20,
#  'El': 18,
#  'código': 14,
#  'aplicaciones': 12,
#  'datos': 11,
#  'Las': 11,
#  'una': 10,
#  'programación': 9,
#  'Los': 9,
#  'a': 9,
#  'desarrollo': 9,
#  'del': 9,
#  'y': 9,
#  'las': 8,
#  'software': 7,
#  'usuario': 7,
#  'permite': 7,
#  'son': 6,
#  'esencial': 5,
#  'diseño': 5,
#  'un': 4,
#  'seguridad': 4,
#  'interfaces': 4,
#  'experiencia': 4,
#  'cambios': 4,
#  'pruebas': 4,
#  'mejora': 4,
#  'clave': 3,
#  'programadores': 3,
#  'fundamental': 3,
#  'crucial': 3,
#  'agilidad': 3,
#  'colaboración': 3,
#  'problemas': 3,
#  'continua': 3,
#  'sistemas': 3,
#  'Python': 2,
#  'trabajo': 2,
#  'con': 2,
#  'optimización': 2,
#  'bases': 2,
#  'web': 2,
#  'aprendizaje': 2,
#  'rama': 2,
#  'calidad': 2,
#  'mantener': 2,
#  'adaptarse': 2,
#  'facilita': 2,
#  'control': 2,
#  'versiones': 2,
#  'otros': 2,
#  'habilidad': 2,
#  'usabilidad': 2,
#  'patrones': 2,
#  'entrega': 2,
#  'útiles': 2,
#  'bibliotecas': 2,
#  'virtualización': 2,
#  'los': 2,
#  'enfoque': 2,
#  'manejar': 2,
#  'prácticas': 2,
#  'facilitan': 2,
#  'machine': 2,
#  'learning': 2,
#  'información': 2,
#  'diferentes': 2,
#  'rendimiento': 2,
#  'gestión': 2,
#  'integración': 2,
#  'como': 2,
#  'identificar': 2,
#  'ágiles': 2,
#  'servidores': 2,
#  'aplicación': 2,
#  'análisis': 2,
#  'Java': 1,
#  'tienen': 1,
#  'alto': 1,
#  'interés': 1,
#  'pasar': 1,
#  'algoritmos': 1,
#  'relacionales': 1,
#  'esenciales': 1,
#  'muchas': 1,
#  'paradigma': 1,
#  'funcional': 1,
#  'gana': 1,
#  'popularidad': 1,
#  'informática': 1,
#  'tema': 1,
#  'lenguajes': 1,
#  'modernos': 1,
#  'ofrecen': 1,
#  'abstracciones': 1,
#  'poderosas': 1,
#  'inteligencia': 1,
#  'artificial': 1,
#  'está': 1,
#  'transformando': 1,
#  'diversas': 1,
#  'industrias': 1,
#  'automático': 1,
#  'ciencia': 1,
#  'intuitivas': 1,
#  'mejoran': 1,
#  'proyecto': 1,
#  'exitoso': 1,
#  'rápidamente': 1,
#  'automatizadas': 1,
#  'cruciales': 1,
#  'garantizar': 1,
#  'estabilidad': 1,
#  'modularización': 1,
#  'equipos': 1,
#  'necesario': 1,
#  'rastrear': 1,
#  'documentación': 1,
#  'clara': 1,
#  'que': 1,
#  'entiendan': 1,
#  'orientada': 1,
#  'objetos': 1,
#  'promueve': 1,
#  'reutilización': 1,
#  'resolución': 1,
#  'prematura': 1,
#  'puede': 1,
#  'llevar': 1,
#  'complicado': 1,
#  'difícil': 1,
#  'atractivas': 1,
#  'limpio': 1,
#  'facilitar': 1,
#  'mantenimiento': 1,
#  'soluciones': 1,
#  'probadas': 1,
#  'comunes': 1,
#  'unitarias': 1,
#  'garantizan': 1,
#  'correcto': 1,
#  'funcionamiento': 1,
#  'partes': 1,
#  'ágil': 1,
#  'prioriza': 1,
#  'valor': 1,
#  'al': 1,
#  'cliente': 1,
#  'comentarios': 1,
#  'deben': 1,
#  'ser': 1,
#  'claros': 1,
#  'recursividad': 1,
#  'técnica': 1,
#  'poderosa': 1,
#  'abierto': 1,
#  'aceleran': 1,
#  'mejor': 1,
#  'utilización': 1,
#  'recursos': 1,
#  'hardware': 1,
#  'prevenir': 1,
#  'ataques': 1,
#  'principios': 1,
#  'SOLID': 1,
#  'fundamentales': 1,
#  'robusto': 1,
#  'arquitectura': 1,
#  'microservicios': 1,
#  'escalar': 1,
#  'componentes': 1,
#  'individualmente': 1,
#  'refactorización': 1,
#  'sin': 1,
#  'cambiar': 1,
#  'su': 1,
#  'comportamiento': 1,
#  'distribuidos': 1,
#  'presentan': 1,
#  'desafíos': 1,
#  'sincronización': 1,
#  'DevOps': 1,
#  'une': 1,
#  'operaciones': 1,
#  'eficiente': 1,
#  'NoSQL': 1,
#  'no': 1,
#  'estructurados': 1,
#  'mercado': 1,
#  'buenas': 1,
#  'concurrente': 1,
#  'eficiencia': 1,
#  'multiusuario': 1,
#  'marcos': 1,
#  'MVC': 1,
#  'separan': 1,
#  'lógica': 1,
#  'interfaz': 1,
#  'interacción': 1,
#  'entre': 1,
#  'se': 1,
#  'logra': 1,
#  'través': 1,
#  'APIs': 1,
#  'máquinas': 1,
#  'aprender': 1,
#  'analítica': 1,
#  'ayuda': 1,
#  'tomar': 1,
#  'decisiones': 1,
#  'basadas': 1,
#  'responsivo': 1,
#  'garantiza': 1,
#  'consistente': 1,
#  'dispositivos': 1,
#  'carga': 1,
#  'verifican': 1,
#  'centrado': 1,
#  'reactiva': 1,
#  'útil': 1,
#  'flujos': 1,
#  'asincrónicos': 1,
#  'contenedores': 1,
#  'implementación': 1,
#  'despliegue': 1,
#  'dependencias': 1,
#  'administrar': 1,
#  'externas': 1,
#  'automatiza': 1,
#  'verificación': 1,
#  'profundo': 1,
#  'avanzada': 1,
#  'depuración': 1,
#  'encontrar': 1,
#  'corregir': 1,
#  'errores': 1,
#  'criptografía': 1,
#  'protege': 1,
#  'sensible': 1,
#  'full-stack': 1,
#  'abarca': 1,
#  'tanto': 1,
#  'frontend': 1,
#  'backend': 1,
#  'ayudan': 1,
#  'vulnerabilidades': 1,
#  'cultural': 1,
#  'adoptar': 1,
#  'manera': 1,
#  'efectiva': 1,
#  'infraestructura': 1,
#  'automatizar': 1,
#  'arquitectónicos': 1,
#  'guían': 1,
#  'estructura': 1,
#  'general': 1,
#  'predictivo': 1,
#  'utiliza': 1,
#  'históricos': 1,
#  'predecir': 1,
#  'tendencias': 1,
#  'API': 1,
#  'REST': 1,
#  'ampliamente': 1,
#  'utilizadas': 1,
#  'comunicarse': 1,
#  'brindar': 1,
#  'buena': 1,
#  'reduce': 1,
#  'costos': 1,
#  'administración': 1,
#  'ingeniería': 1,
#  'implica': 1,
#  'métodos': 1,
#  'sistemáticos': 1,
#  'autodocumentado': 1,
#  'claro': 1,
#  'fácil': 1,
#  'entender': 1,
#  'conecta': 1,
#  'trabajar': 1,
#  'juntas': 1,
#  'metodologías': 1,
#  'promueven': 1,
#  'adaptación': 1,
#  'monitoreo': 1,
#  'resolver': 1,
#  'tiempo': 1,
#  'real': 1,
#  'masivos': 1,
#  '(big': 1,
#  'data)': 1,
#  'abre': 1,
#  'oportunidades': 1,
#  'obtener': 1,
#  'insights': 1,
#  'proceso': 1,
#  'constante': 1,
#  'mitigación': 1,
#  'riesgos': 1}

# %%
def indice_invertido(lista):
    indice = {}
    for i, columna in enumerate(lista):
        for palabra in columna.split():
            if palabra in indice:
                indice[palabra].append(i)
            else:
                indice[palabra] = [i]
    return indice

# %%
indice_invertido(my_documents)
# Out:
# {'La': [0,
#   2,
#   5,
#   7,
#   10,
#   11,
#   13,
#   15,
#   16,
#   17,
#   18,
#   25,
#   27,
#   28,
#   30,
#   31,
#   35,
#   37,
#   39,
#   41,
#   45,
#   47,
#   48,
#   50,
#   51,
#   54,
#   55,
#   60,
#   61,
#   63,
#   68],
#  'programación': [0, 4, 6, 16, 17, 25, 28, 37, 45],
#  'en': [0,
#   1,
#   1,
#   2,
#   5,
#   11,
#   13,
#   14,
#   17,
#   24,
#   25,
#   28,
#   32,
#   35,
#   36,
#   37,
#   41,
#   42,
#   44,
#   48,
#   51,
#   53,
#   65,
#   68],
#  'Python': [0, 1],
#  'es': [0,
#   2,
#   5,
#   8,
#   10,
#   14,
#   15,
#   17,
#   20,
#   25,
#   28,
#   45,
#   47,
#   49,
#   50,
#   54,
#   59,
#   62,
#   67,
#   68],
#  'clave': [0, 8, 54],
#  'para': [0,
#   3,
#   10,
#   12,
#   14,
#   15,
#   20,
#   21,
#   28,
#   29,
#   33,
#   34,
#   45,
#   47,
#   50,
#   54,
#   57,
#   58,
#   59,
#   62,
#   63,
#   66,
#   67],
#  'el': [0,
#   2,
#   5,
#   11,
#   14,
#   15,
#   20,
#   22,
#   24,
#   26,
#   29,
#   33,
#   35,
#   36,
#   43,
#   44,
#   46,
#   48,
#   52,
#   52,
#   53,
#   68],
#  'trabajo': [0, 38],
#  'con': [0, 58],
#  'datos': [0, 3, 8, 32, 34, 34, 40, 41, 45, 57, 66],
#  'Los': [1, 6, 21, 24, 29, 32, 38, 46, 56],
#  'programadores': [1, 13, 62],
#  'Java': [1],
#  'tienen': [1],
#  'un': [1, 5, 10, 68],
#  'alto': [1],
#  'interés': [1],
#  'pasar': [1],
#  'a': [1, 11, 16, 18, 35, 39, 40, 41, 53],
#  'optimización': [2, 18],
#  'de': [2,
#   2,
#   3,
#   4,
#   5,
#   6,
#   8,
#   8,
#   9,
#   11,
#   13,
#   14,
#   16,
#   17,
#   18,
#   19,
#   19,
#   19,
#   21,
#   22,
#   23,
#   26,
#   26,
#   27,
#   27,
#   29,
#   30,
#   32,
#   34,
#   36,
#   38,
#   38,
#   38,
#   39,
#   40,
#   41,
#   43,
#   43,
#   44,
#   45,
#   46,
#   47,
#   48,
#   53,
#   54,
#   55,
#   56,
#   59,
#   60,
#   61,
#   61,
#   62,
#   63,
#   65,
#   66,
#   67,
#   67,
#   68,
#   68],
#  'algoritmos': [2],
#  'fundamental': [2, 15, 28],
#  'desarrollo': [2, 5, 11, 23, 26, 33, 35, 52, 68],
#  'software': [2, 11, 12, 26, 29, 53, 61],
#  'Las': [3, 9, 12, 22, 26, 34, 36, 43, 53, 58, 64],
#  'bases': [3, 34],
#  'relacionales': [3],
#  'son': [3, 12, 21, 29, 34, 58],
#  'esenciales': [3],
#  'muchas': [3],
#  'aplicaciones': [3, 5, 19, 39, 43, 44, 46, 51, 58, 59, 63, 65],
#  'El': [4, 8, 14, 19, 20, 23, 33, 40, 42, 44, 49, 52, 57, 59, 62, 65, 66, 67],
#  'paradigma': [4],
#  'funcional': [4],
#  'gana': [4],
#  'popularidad': [4],
#  'seguridad': [5, 28, 53, 68],
#  'informática': [5],
#  'tema': [5],
#  'crucial': [5, 50, 67],
#  'web': [5, 28],
#  'lenguajes': [6],
#  'modernos': [6],
#  'ofrecen': [6],
#  'abstracciones': [6],
#  'poderosas': [6],
#  'inteligencia': [7],
#  'artificial': [7],
#  'está': [7],
#  'transformando': [7],
#  'diversas': [7],
#  'industrias': [7],
#  'aprendizaje': [8, 49],
#  'automático': [8],
#  'una': [8, 17, 25, 27, 33, 42, 49, 50, 56, 59],
#  'rama': [8, 49],
#  'la': [8,
#   9,
#   12,
#   13,
#   16,
#   17,
#   19,
#   23,
#   25,
#   28,
#   31,
#   32,
#   36,
#   37,
#   38,
#   38,
#   44,
#   46,
#   48,
#   51,
#   55,
#   56,
#   60,
#   61,
#   64,
#   64,
#   67],
#  'ciencia': [8],
#  'interfaces': [9, 19, 58, 67],
#  'usuario': [9, 9, 19, 38, 44, 67, 67],
#  'intuitivas': [9],
#  'mejoran': [9],
#  'experiencia': [9, 42, 59, 67],
#  'del': [9, 10, 12, 13, 22, 31, 35, 49, 67],
#  'calidad': [10, 31],
#  'código': [10, 13, 14, 15, 16, 18, 20, 22, 24, 26, 31, 48, 55, 62],
#  'esencial': [10, 17, 20, 47, 59],
#  'mantener': [10, 18],
#  'proyecto': [10],
#  'exitoso': [10],
#  'agilidad': [11, 35, 54],
#  'permite': [11, 27, 30, 35, 40, 55, 65],
#  'adaptarse': [11, 35],
#  'cambios': [11, 14, 35, 48],
#  'rápidamente': [11],
#  'pruebas': [12, 22, 43, 53],
#  'automatizadas': [12],
#  'cruciales': [12],
#  'garantizar': [12],
#  'estabilidad': [12],
#  'modularización': [13],
#  'facilita': [13, 60],
#  'colaboración': [13, 36, 64],
#  'equipos': [13],
#  'control': [14, 36],
#  'versiones': [14, 36],
#  'necesario': [14],
#  'rastrear': [14],
#  'documentación': [15],
#  'clara': [15],
#  'que': [15],
#  'otros': [15, 62],
#  'entiendan': [15],
#  'orientada': [16],
#  'objetos': [16],
#  'promueve': [16],
#  'reutilización': [16],
#  'resolución': [17],
#  'problemas': [17, 21, 65],
#  'habilidad': [17, 50],
#  'prematura': [18],
#  'puede': [18],
#  'llevar': [18],
#  'complicado': [18],
#  'y': [18, 24, 33, 46, 50, 60, 62, 64, 65],
#  'difícil': [18],
#  'diseño': [19, 21, 29, 42, 67],
#  'atractivas': [19],
#  'mejora': [19, 31, 37, 44],
#  'usabilidad': [19, 44],
#  'las': [19, 22, 33, 40, 43, 44, 47, 59],
#  'limpio': [20],
#  'facilitar': [20],
#  'mantenimiento': [20],
#  'patrones': [21, 56],
#  'soluciones': [21],
#  'probadas': [21],
#  'comunes': [21],
#  'unitarias': [22],
#  'garantizan': [22],
#  'correcto': [22],
#  'funcionamiento': [22],
#  'partes': [22],
#  'ágil': [23],
#  'prioriza': [23],
#  'entrega': [23, 33],
#  'continua': [23, 48, 64],
#  'valor': [23],
#  'al': [23],
#  'cliente': [23],
#  'comentarios': [24],
#  'deben': [24],
#  'ser': [24],
#  'claros': [24],
#  'útiles': [24, 34],
#  'recursividad': [25],
#  'técnica': [25],
#  'poderosa': [25],
#  'bibliotecas': [26, 47],
#  'abierto': [26],
#  'aceleran': [26],
#  'virtualización': [27, 60],
#  'mejor': [27],
#  'utilización': [27],
#  'los': [27, 40],
#  'recursos': [27],
#  'hardware': [27],
#  'prevenir': [28],
#  'ataques': [28],
#  'principios': [29],
#  'SOLID': [29],
#  'fundamentales': [29],
#  'robusto': [29],
#  'arquitectura': [30],
#  'microservicios': [30],
#  'escalar': [30],
#  'componentes': [30],
#  'individualmente': [30],
#  'refactorización': [31],
#  'sin': [31],
#  'cambiar': [31],
#  'su': [31],
#  'comportamiento': [31],
#  'sistemas': [32, 37, 63],
#  'distribuidos': [32],
#  'presentan': [32],
#  'desafíos': [32],
#  'sincronización': [32],
#  'enfoque': [33, 44],
#  'DevOps': [33],
#  'une': [33],
#  'operaciones': [33],
#  'eficiente': [33],
#  'NoSQL': [34],
#  'manejar': [34, 45],
#  'no': [34],
#  'estructurados': [34],
#  'mercado': [35],
#  'buenas': [36],
#  'prácticas': [36, 54],
#  'facilitan': [36, 46],
#  'concurrente': [37],
#  'eficiencia': [37],
#  'multiusuario': [37],
#  'marcos': [38],
#  'MVC': [38],
#  'separan': [38],
#  'lógica': [38],
#  'interfaz': [38],
#  'interacción': [39],
#  'entre': [39],
#  'se': [39],
#  'logra': [39],
#  'través': [39],
#  'APIs': [39],
#  'machine': [40, 49],
#  'learning': [40, 49],
#  'máquinas': [40],
#  'aprender': [40],
#  'analítica': [41],
#  'ayuda': [41],
#  'tomar': [41],
#  'decisiones': [41],
#  'basadas': [41],
#  'información': [41, 51],
#  'responsivo': [42],
#  'garantiza': [42],
#  'consistente': [42],
#  'diferentes': [42, 63],
#  'dispositivos': [42],
#  'carga': [43],
#  'verifican': [43],
#  'rendimiento': [43, 59],
#  'centrado': [44],
#  'reactiva': [45],
#  'útil': [45],
#  'flujos': [45],
#  'asincrónicos': [45],
#  'contenedores': [46],
#  'implementación': [46],
#  'despliegue': [46],
#  'gestión': [47, 55],
#  'dependencias': [47],
#  'administrar': [47],
#  'externas': [47],
#  'integración': [48, 63],
#  'automatiza': [48],
#  'verificación': [48],
#  'profundo': [49],
#  'avanzada': [49],
#  'depuración': [50],
#  'encontrar': [50],
#  'corregir': [50],
#  'errores': [50],
#  'criptografía': [51],
#  'protege': [51],
#  'sensible': [51],
#  'full-stack': [52],
#  'abarca': [52],
#  'tanto': [52],
#  'frontend': [52],
#  'como': [52, 55],
#  'backend': [52],
#  'ayudan': [53],
#  'identificar': [53, 65],
#  'vulnerabilidades': [53],
#  'cultural': [54],
#  'adoptar': [54],
#  'ágiles': [54, 64],
#  'manera': [54],
#  'efectiva': [54],
#  'infraestructura': [55],
#  'automatizar': [55],
#  'servidores': [55, 60],
#  'arquitectónicos': [56],
#  'guían': [56],
#  'estructura': [56],
#  'general': [56],
#  'aplicación': [56, 61],
#  'análisis': [57, 66],
#  'predictivo': [57],
#  'utiliza': [57],
#  'históricos': [57],
#  'predecir': [57],
#  'tendencias': [57],
#  'API': [58],
#  'REST': [58],
#  'ampliamente': [58],
#  'utilizadas': [58],
#  'comunicarse': [58],
#  'brindar': [59],
#  'buena': [59],
#  'reduce': [60],
#  'costos': [60],
#  'administración': [60],
#  'ingeniería': [61],
#  'implica': [61],
#  'métodos': [61],
#  'sistemáticos': [61],
#  'autodocumentado': [62],
#  'claro': [62],
#  'fácil': [62],
#  'entender': [62],
#  'conecta': [63],
#  'trabajar': [63],
#  'juntas': [63],
#  'metodologías': [64],
#  'promueven': [64],
#  'adaptación': [64],
#  'monitoreo': [65],
#  'resolver': [65],
#  'tiempo': [65],
#  'real': [65],
#  'masivos': [66],
#  '(big': [66],
#  'data)': [66],
#  'abre': [66],
#  'oportunidades': [66],
#  'obtener': [66],
#  'insights': [66],
#  'proceso': [68],
#  'constante': [68],
#  'mitigación': [68],
#  'riesgos': [68]}
